# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-98ec7071-6f4d-419e-95ae-c1ce25fb3531" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98ec7071-6f4d-419e-95ae-c1ce25fb3531">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install tensorflow keras matplotlib

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
import matplotlib.pyplot as plt

# %%
import os
os.listdir()
# Out:
# ['.config', 'archive.zip', 'sample_data']

# %%
os.listdir('dataset')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_459/3350789131.py in <cell line: 0>()
# ----> 1 os.listdir('dataset')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset'

# %%
import os
os.listdir()
# Out:
# ['.config', 'archive.zip', 'sample_data']

# %%
# !unzip archive.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: C-NMC_Leukemia/training_data/fold_2/all/UID_25_12_5_all.bmp
#   inflating: C-NMC_Leukemia/training_data/fold_2/all/UID_25_12_6_all.bmp
#   inflating: C-NMC_Leukemia/training_data/fold_2/all/UID_25_12_7_all.bmp
#   inflating: C-NMC_Leukemia/training_data/fold_2/all/UID_25_13_1_all.bmp
#   inflating: C-NMC_Leukemia/training_data/fold_2/all/UID_25_13_2_all.bmp
#   inflating: C-NMC_Leukemia/training_data/fold_2/all/UID_25_13_3_all.bmp
#   inflating: C-NMC_Leukemia/training_data/fold_2/all/UID_25_14_1_all.bmp
#   inflating: C-NMC_Leukemia/training_data/fold_2/all/UID_25_14_2_all.bmp
#   inflating: C-NMC_Leukemia/training_data/fold_2/all/UID_25_14_3_all.bmp
#   inflating: C-NMC_Leukemia/training_data/fold_2/all/UID_25_14_4_all.bmp
#   inflating: C-NMC_Leukemia/training_data/fold_2/all/UID_25_14_5_all.bmp
#   inflating: C-NMC_Leukemia/training_data/fold_2/all/UID_25_14_6_all.bmp
# ...

# %%
import os
os.listdir()
# Out:
# ['.config', 'archive.zip', 'C-NMC_Leukemia', 'sample_data']

# %%
os.listdir('C-NMC_Leukemia')
# Out:
# ['validation_data', 'training_data', 'testing_data']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_data = train_datagen.flow_from_directory(
    'C-NMC_Leukemia/training_data',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'
)

val_data = val_datagen.flow_from_directory(
    'C-NMC_Leukemia/validation_data',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'
)

test_data = test_datagen.flow_from_directory(
    'C-NMC_Leukemia/testing_data',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 10661 images belonging to 3 classes.
# Found 1867 images belonging to 1 classes.
# Found 2586 images belonging to 1 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential([
    Conv2D(32,(3,3),activation='relu',input_shape=(64,64,3)),
    MaxPooling2D(2,2),

    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),

    Dense(128,activation='relu'),
    Dense(3,activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.3527 - loss: 1.0965
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_459/793212840.py in <cell line: 0>()
# ----> 1 history = model.fit(
#       2     train_data,
#       3     validation_data=val_data,
#       4     epochs=10
#       5 )
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
# ...

# %%
train_data = train_datagen.flow_from_directory(
    'C-NMC_Leukemia/training_data',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'
)

val_data = val_datagen.flow_from_directory(
    'C-NMC_Leukemia/validation_data',
    target_size=(64,64),
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical',
    classes=train_data.class_indices.keys()
)

test_data = test_datagen.flow_from_directory(
    'C-NMC_Leukemia/testing_data',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical',
    classes=train_data.class_indices.keys()
)
# Out:
# Found 10661 images belonging to 3 classes.
#   File "/tmp/ipykernel_459/3446242362.py", line 11
#     target_size=(64,64),
#     ^
# SyntaxError: keyword argument repeated: target_size

# %%
train_data = train_datagen.flow_from_directory(
    'C-NMC_Leukemia/training_data',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'
)

val_data = val_datagen.flow_from_directory(
    'C-NMC_Leukemia/validation_data',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical',
    classes=list(train_data.class_indices.keys())
)

test_data = test_datagen.flow_from_directory(
    'C-NMC_Leukemia/testing_data',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical',
    classes=list(train_data.class_indices.keys())
)
# Out:
# Found 10661 images belonging to 3 classes.
# Found 0 images belonging to 3 classes.
# Found 0 images belonging to 3 classes.

# %%
import os
os.listdir('C-NMC_Leukemia/validation_data')
# Out:
# ['C-NMC_test_prelim_phase_data', 'C-NMC_test_prelim_phase_data_labels.csv']

# %%
train_data = train_datagen.flow_from_directory(
    'C-NMC_Leukemia/training_data',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'
)

val_data = val_datagen.flow_from_directory(
    'C-NMC_Leukemia/validation_data',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 10661 images belonging to 3 classes.
# Found 1867 images belonging to 1 classes.

# %%
train_data = train_datagen.flow_from_directory(
    'C-NMC_Leukemia/training_data',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'
)

val_data = val_datagen.flow_from_directory(
    'C-NMC_Leukemia/validation_data',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical',
    classes=list(train_data.class_indices.keys())
)
# Out:
# Found 10661 images belonging to 3 classes.
# Found 0 images belonging to 3 classes.

# %%
import os
os.listdir('C-NMC_Leukemia/validation_data')
# Out:
# ['C-NMC_test_prelim_phase_data', 'C-NMC_test_prelim_phase_data_labels.csv']

# %%
os.listdir('C-NMC_Leukemia/validation_data/C-NMC_val_phase_data')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_459/3865013154.py in <cell line: 0>()
# ----> 1 os.listdir('C-NMC_Leukemia/validation_data/C-NMC_val_phase_data')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C-NMC_Leukemia/validation_data/C-NMC_val_phase_data'

# %%
import os
os.listdir('C-NMC_Leukemia/validation_data')
# Out:
# ['C-NMC_test_prelim_phase_data', 'C-NMC_test_prelim_phase_data_labels.csv']

# %%
os.listdir('C-NMC_Leukemia/training_data')
# Out:
# ['fold_2', 'fold_0', 'fold_1']

# %%
train_data = train_datagen.flow_from_directory(
    'C-NMC_Leukemia/training_data',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 10661 images belonging to 3 classes.

# %%
history = model.fit(
    train_data,
    epochs=10
)
# Out:
# Epoch 1/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 64s 191ms/step - accuracy: 0.3856 - loss: 1.0869
# Epoch 2/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 48s 142ms/step - accuracy: 0.4009 - loss: 1.0793
# Epoch 3/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 45s 134ms/step - accuracy: 0.4224 - loss: 1.0640
# Epoch 4/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 45s 134ms/step - accuracy: 0.4494 - loss: 1.0330
# Epoch 5/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 44s 132ms/step - accuracy: 0.4816 - loss: 1.0002
# Epoch 6/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 43s 128ms/step - accuracy: 0.5270 - loss: 0.9470
# Epoch 7/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 48s 143ms/step - accuracy: 0.5686 - loss: 0.8923
# Epoch 8/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 50s 150ms/step - accuracy: 0.6057 - loss: 0.8332
# Epoch 9/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 44s 131ms/step - accuracy: 0.6458 - loss: 0.7719
# Epoch 10/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 45s 133ms/step - accuracy: 0.6803 - loss: 0.7205

# %%
model.save("leukemia_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save("leukemia_model.keras")

# %%
from google.colab import files
files.download("leukemia_model.keras")

# %%
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open("leukemia_model.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpa7tq8c3b'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   138421417133648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138421417134800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138421417135184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138421417134224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138421417133840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138421417135376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138421417132304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138421417134032: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
files.download("leukemia_model.tflite")

# %%
import numpy as np

for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        print(layer.name)
        print("Weights shape:", weights[0].shape)
# Out:
# conv2d
# Weights shape: (3, 3, 3, 32)
# conv2d_1
# Weights shape: (3, 3, 32, 64)
# dense
# Weights shape: (12544, 128)
# dense_1
# Weights shape: (128, 3)

# %%
import numpy as np

np.save("cnn_weights.npy", np.array(model.get_weights(), dtype=object), allow_pickle=True)

# %%
from google.colab import files
files.download("cnn_weights.npy")

# %%
weights = model.get_weights()

with open("cnn_weights.txt","w") as f:
    for w in weights:
        flat = w.flatten()
        for value in flat:
            f.write(str(value) + "\n")

# %%
files.download("cnn_weights.txt")

# %%
import numpy as np

weights = np.load("cnn_weights.npy", allow_pickle=True)

scale = 256

with open("cnn_weights.mem","w") as f:
    for layer in weights:
        flat = layer.flatten()
        for v in flat:
            fixed = int(v * scale)
            f.write(str(fixed) + "\n")

# %%
from google.colab import files
files.download("cnn_weights.mem")
